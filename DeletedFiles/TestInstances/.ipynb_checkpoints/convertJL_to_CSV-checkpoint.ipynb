# %%
# Out:
# 0.253

# %%
using CSV
include("./N4_1.jl")

timesFile = open("./test.txt", "r")
for e =1:Len
    println(timesFile, edge[e,1],"\t",edge[e,2])
end

close(timesFile)
# println(timesFile, dataSet, "; Ins ", Ins, "; Time ", total_time, "; MP_obj ", MP_obj, "; x_now ", findall(x_now.==1),"; Cells ", nrow(df_cell), "; Iter ", iter)#, "; W ", LB_w, "; Cuts ", numConv)
# close(timesFile)
# Out:
# ArgumentError: write failed, IOStream is not writeable
#
# Stacktrace:
#  [1] unsafe_write(s::IOStream, p::Ptr{UInt8}, nb::UInt64)
#    @ Base ./iostream.jl:373
#  [2] write
#    @ ./strings/io.jl:244 [inlined]
#  [3] show
#    @ ./show.jl:1142 [inlined]
#  [4] print(io::IOStream, x::Int64)
#    @ Base ./strings/io.jl:35
#  [5] print(::IOStream, ::Int64, ::String, ::Vararg{Any})
#    @ Base ./strings/io.jl:46
#  [6] println(::IOStream, ::Int64, ::Vararg{Any})
#    @ Base ./strings/io.jl:75
#  [7] top-level scope
#    @ ./In[30]:3
