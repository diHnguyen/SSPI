# %%
#Convert .jl to .py
import pandas as pd
# Read a CSV file into a DataFrame
with open("./N25/N25_108.jl",'r') as f:
    lines = f.readlines()
    for line in lines:
        if line.startswith('edge'):
            print(line)
# Out:
# edge = [1 6; 1 20; 2 19; 2 23; 3 10; 3 12; 3 20; 4 20; 4 21; 5 6; 5 17; 5 23; 6 2; 6 9; 6 10; 6 17; 6 18; 7 4; 8 6; 8 10; 8 22; 9 24; 9 25; 10 2; 10 11; 10 16; 11 19; 11 20; 11 21; 12 7; 12 11; 12 14; 13 2; 13 20; 13 21; 14 21; 15 3; 15 7; 16 6; 16 24; 16 25; 17 6; 17 8; 17 13; 17 16; 18 9; 18 14; 18 24; 19 2; 19 5; 19 9; 19 10; 19 15; 19 21; 20 13; 20 14; 21 24; 22 14; 22 15; 23 9; 23 15; 23 21; 23 22; 24 12; 24 17]

# %%
pwd()
# Out:
# '/Users/dinguyen/Desktop/Local Documents/GitHub/Paper5/TestInstances'
