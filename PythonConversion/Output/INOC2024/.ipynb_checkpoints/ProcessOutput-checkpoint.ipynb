# %%
import pandas as pd
import os
def processSeqSampling(EXP, N):
    # output = pd.DataFrame(columns="num")
    # output.columns = 
    prefixed = [filename for filename in os.listdir('./') if filename.startswith("SeqSampling_N"+str(N)+"_")]
    print(prefixed)
    dfs_list = [pd.read_csv(file, sep=';', names=['num_cases','total_time','b','ObjVal','x_sol','var','opt_gap','iter','para'], header=None) for file in prefixed]
    # print(dfs_list[0])
    output = pd.concat(dfs_list, axis=0, ignore_index=True)
    # print(output)
    # for i in range(5):
    #     output = pd.read_csv(EXP+"_N"+str(N)+"_"+str(i+1)+".txt", sep=";", header=None)
        
    return output


EXP = 'SeqSampling'
N = 10
output = processSeqSampling(EXP, N)
output
# Out:
# ['SeqSampling_N10_4.txt', 'SeqSampling_N10_5.txt', 'SeqSampling_N10_1.txt', 'SeqSampling_N10_2.txt', 'SeqSampling_N10_3.txt']
#     A          B  C           D        E             F          G   H  \
# 0  49   1.594740  2   35.937095    [4 6]  1.203329e+02   6.331572  23
# 1  49   1.387805  2  173.646302  [ 0 22]  2.525407e-27  56.000000  20
# 2  49   0.654536  2   76.000000  [ 2 30]  1.811915e-30   2.000000   7
# 3  49   0.815751  2  277.000000  [ 0 18]  4.529787e-31   1.000000   9
# 4  49  18.419930  2  232.120182    [4 5]  4.798603e+01  57.561440  67
#
#                                                    I
# 0  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 1  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 2  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 3  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 4  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...

# %%
import os
files = os.listdir("./")
for file in files:
    if file.startswith("SeqSampling"):
        print(file)
# dfs_list = [pd.read_csv(file, sep='\s+') for file in files]
# Out:
# SeqSampling_N10_4.txt
# SeqSampling_N10_5.txt
# SeqSampling_N10_1.txt
# SeqSampling_N10_2.txt
# SeqSampling_N10_3.txt
# SeqSampling_N100_1.txt
# SeqSampling_N100_2.txt
# SeqSampling_N100_3.txt
# SeqSampling_N100_4.txt
# SeqSampling_N100_5.txt

# %%
dfs_list = pd.DataFrame(columns=['A','B','C','D','E','F','G'])
prefixed = [filename for filename in os.listdir('./') if filename.startswith("SeqSampling_N10_")]
dfs_list = [pd.read_csv(file, sep=';', names=['A','B','C','D','E','F','G','H','I'], header=None) for file in prefixed]
data_frame_result = pd.concat(dfs_list, axis=0, ignore_index=True)
data_frame_result
# Out:
#     A          B  C           D        E             F          G   H  \
# 0  49   1.594740  2   35.937095    [4 6]  1.203329e+02   6.331572  23
# 1  49   1.387805  2  173.646302  [ 0 22]  2.525407e-27  56.000000  20
# 2  49   0.654536  2   76.000000  [ 2 30]  1.811915e-30   2.000000   7
# 3  49   0.815751  2  277.000000  [ 0 18]  4.529787e-31   1.000000   9
# 4  49  18.419930  2  232.120182    [4 5]  4.798603e+01  57.561440  67
#
#                                                    I
# 0  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 1  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 2  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 3  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...
# 4  0.425,0.015,2e-07,1e-07,0.1,8.14491246025,1000...

# %%
dfs_list = pd.DataFrame(columns=['A','B','C','D','E','F','G','H','I'])
dfs_list
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F, G, H, I]
# Index: []
