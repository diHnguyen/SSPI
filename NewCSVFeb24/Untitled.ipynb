# %%
import gurobipy
# from gurobipy import GRB
import

# %%
print(gurobipy._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(gurobipy._version_)
#
# AttributeError: module 'gurobipy' has no attribute '_version_'
